# %%
# %matplotlib inline
from modsim import *
from tabula import read_pdf
from pandas import read_html
from numpy import random
table1 = read_html('USASAC2015-Report#27-2014-Activities 8.html')
product_tables = read_html('USASAC2015-Report#27-2014-Activities 10.html')
table2= read_html('USASAC2015-Report#27-2014-Activities 97-11.html')
table3 = read_html('USASAC2015-Report#27-2014-Activities 98-12.html')
return_97 = table2[0]
return_98 = table3[0]

# %%
aqua_prdt = product_tables[0]
aqua_prdt.columns = ['year','production']
#aqua_prdt.production[15] = 2381
aqua_prdt.index = aqua_prdt.year
#aqua_prdt
random([10])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-63-0d1fae529e85> in <module>()
#       4 aqua_prdt.index = aqua_prdt.year
#       5 #aqua_prdt
# ----> 6 random([10])
#
# TypeError: 'module' object is not callable

# %%
salmon_pop = table1[0]
salmon_pop.columns = ['year','1sw', '2sw','3sw', 'repeat', 'total','hatchery', 'natural']
salmon_pop.index = salmon_pop.year
#salmon_popu = salmon_pop.hatchery + salmon_pop.natural
pop_total = salmon_pop.natural + salmon_pop.hatchery
salmon_pop
# Out:
#       year   1sw   2sw  3sw  repeat  total  hatchery  natural
# year
# 1967  1967    75   574   39      93    781       114      667
# 1968  1968    18   498   12      56    584       314      270
# 1969  1969    32   430   16      34    512       108      404
# 1970  1970     9   539   15      17    580       162      418
# 1971  1971    31   407   11       5    454       177      277
# 1972  1972    24   946   38      17   1025       495      530
# 1973  1973    18   623    8      13    662       422      240
# 1974  1974    52   791   35      25    903       639      264
# 1975  1975    77  1250   14      30   1371      1126      245
# 1976  1976   172   836    6      16   1030       933       97
# 1977  1977    63  1027    7      33   1130       921      209
# 1978  1978   145  2269   17      33   2464      2082      382
# 1979  1979   225   972    6      21   1224      1039      185
# 1980  1980   707  3437   11      57   4212      3870      342
# 1981  1981   789  3738   43      84   4654      4428      226
# 1982  1982   294  4388   19      42   4743      4489      254
# 1983  1983   239  1255   18      14   1526      1270      256
# 1984  1984   387  1969   21      52   2429      1988      441
# 1985  1985   302  3913   13      21   4249      3594      655
# 1986  1986   582  4688   28      13   5311      4597      714
# 1987  1987   807  2191   96     132   3226      2896      330
# 1988  1988   755  2386   10      67   3218      3015      203
# 1989  1989   992  2461   11      43   3507      3157      350
# 1990  1990   575  3744   18      38   4375      3785      590
# 1991  1991   255  2289    5      62   2611      1602     1009
# 1992  1992  1056  2255    6      20   3337      2678      659
# 1993  1993   405  1953   11      37   2406      1971      435
# 1994  1994   342  1266    2      25   1635      1228      407
# 1995  1995   168  1582    7      23   1780      1484      296
# 1996  1996   574  2168   13      43   2798      2092      706
# 1997  1997   278  1492    8      36   1814      1296      518
# 1998  1998   340  1477    3      42   1862      1146      716
# 1999  1999   402  1136    3      26   1567       959      608
# 2000  2000   292   535    0      20    847       562      285
# 2001  2001   269   804    7       4   1084       833      251
# 2002  2002   437   505    2      23    967       832      135
# 2003  2003   233  1185    3       6   1427      1238      189
# 2004  2004   319  1266   21      24   1630      1395      235
# 2005  2005   317   945    0      10   1272      1019      253
# 2006  2006   442  1007    2       5   1456      1167      289
# 2007  2007   299   958    3       1   1261       940      321
# 2008  2008   812  1758   12      23   2605      2191      414
# 2009  2009   243  2065   16      16   2340      2017      323
# 2010  2010   552  1081    2      16   1651      1468      183
# 2011  2011  1084  3053   26      15   4178      3560      618
# 2012  2012    26   879   31       5    941       731      210
# 2013  2013    78   525    3       5    611       413      198
# 2014  2014   110   334    3       3    450       304      146

# %%
production = aqua_prdt.production
return_97.columns = ['year','1sw', '2sw','3sw', 'repeat', 'total','hatchery', 'natural']
return_97.index = return_97.year
return_97
# Out:
#       year   1sw   2sw  3sw  repeat  total  hatchery  natural
# year
# 1997  1997   278  1492    8      36   1814      1296      518
# 1998  1998   340  1477    3      42   1862      1146      716
# 1999  1999   402  1136    3      26   1567       959      608
# 2000  2000   292   535    0      20    847       562      285
# 2001  2001   269   804    7       4   1084       833      251
# 2002  2002   437   505    2      23    967       832      135
# 2003  2003   233  1185    3       6   1427      1238      189
# 2004  2004   319  1266   21      24   1630      1395      235
# 2005  2005   317   945    0      10   1272      1019      253
# 2006  2006   442  1007    2       5   1456      1167      289
# 2007  2007   299   958    3       1   1261       940      321
# 2008  2008   812  1758   12      23   2605      2191      414
# 2009  2009   243  2065   16      16   2340      2017      323
# 2010  2010   552  1081    2      16   1651      1468      183
# 2011  2011  1084  3053   26      15   4178      3560      618

# %%
newfig()
plot(salmon_pop.index, salmon_pop.total, 'bs:')

# %%
newfig()
plot(aqua_prdt.index, production, 'go:')

# %%
newfig()
plot(production, return_97.total, 'ro')
decorate(xlabel = 'Aquacultural Production(metric tons)',
         ylabel = 'Atlantic Salmon Returns')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
production = aqua_prdt.production
return_98.columns = ['year','1sw', '2sw','3sw', 'repeat', 'total','hatchery', 'natural']
return_98.index = return_97.year
return_98
# Out:
#       year   1sw   2sw  3sw  repeat  total  hatchery  natural
# year
# 1997  1998   340  1477    3      42   1862      1146      716
# 1998  1999   402  1136    3      26   1567       959      608
# 1999  2000   292   535    0      20    847       562      285
# 2000  2001   269   804    7       4   1084       833      251
# 2001  2002   437   505    2      23    967       832      135
# 2002  2003   233  1185    3       6   1427      1238      189
# 2003  2004   319  1266   21      24   1630      1395      235
# 2004  2005   317   945    0      10   1272      1019      253
# 2005  2006   442  1007    2       5   1456      1167      289
# 2006  2007   299   958    3       1   1261       940      321
# 2007  2008   812  1758   12      23   2605      2191      414
# 2008  2009   243  2065   16      16   2340      2017      323
# 2009  2010   552  1081    2      16   1651      1468      183
# 2010  2011  1084  3053   26      15   4178      3560      618
# 2011  2012    26   879   31       5    941       731      210

# %%
plot(production, return_98.total, 'ro')
decorate(xlabel = 'Aquacultural Production(metric tons)',
         ylabel = 'Atlantic Salmon Returns')
# Out:
# C:\ProgramData\Miniconda3\lib\site-packages\matplotlib\axes\_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
